# %%
import pandas as pd
import re
import csv
from tqdm import tqdm
import torch
from transformers import pipeline, BitsAndBytesConfig
import os
import json

# --- Configuration ---
# Set the Hugging Face cache directory to a larger storage location
cache_dir = '/scratch/project_2004147/.cache/huggingface/hub'
os.environ['HF_HOME'] = cache_dir
os.makedirs(cache_dir, exist_ok=True) 

INPUT_FILENAME = 'bertopic_with_zeroshot_chatgpt/df_with_final_predictions.csv'
OUTPUT_FILENAME = 'bertopic_with_zeroshot_chatgpt/df_with_geo_predictions_mistral_v2.csv'
BACKUP_FILENAME = 'bertopic_with_zeroshot_chatgpt/df_with_geo_predictions_mistral_backup_v2.csv'
BACKUP_INTERVAL = 1000 

def extract_country_info_mistral(text, pipe):
    """
    Analyzes a tweet's text using a Mistral-based model to extract the country,
    confidence, and evidence by prompting for a JSON output.
    """
    if not isinstance(text, str) or not text.strip():
        return 'N/A', 'N/A', 'N/A'

    # A more sophisticated prompt asking for a structured JSON response.
    prompt = (
        "Analyze the following tweet and extract the country. "
        "Provide your answer as a JSON object with three keys: "
        "\"country\" (the country name), "
        "\"confidence\" (one of: \"High\", \"Moderate\", \"Low\", or \"N/A\"), and "
        "\"evidence\" (the specific word or phrase from the tweet that indicates the country). "
        "If no country is mentioned, the value for all keys should be \"N/A\".\n\n"
        f"Tweet: \"{text}\"\n\n"
        "JSON Answer:"
    )
    
    try:
        # Generate the response from the model
        outputs = pipe(prompt, max_new_tokens=50, do_sample=False, pad_token_id=pipe.tokenizer.eos_token_id)
        generated_text = outputs[0]['generated_text']
        
        # Extract just the JSON part of the answer
        json_part = generated_text[len(prompt):].strip()
        
        # Find the JSON object within the generated text
        match = re.search(r'\{.*\}', json_part, re.DOTALL)
        if not match:
            return 'Parse Error', 'Low', 'No JSON object found'

        # Parse the JSON string
        data = json.loads(match.group(0))
        
        country = data.get('country', 'N/A')
        confidence = data.get('confidence', 'N/A')
        evidence = data.get('evidence', 'N/A')

        # Handle cases where the model returns empty strings or None
        if not country or country.lower() == 'n/a':
            return 'N/A', 'N/A', 'N/A'

        return country, confidence, evidence

    except json.JSONDecodeError:
        return 'Parse Error', 'Low', f"Invalid JSON: {json_part}"
    except Exception as e:
        print(f"An error occurred during model inference: {e}")
        return 'Error', 'Error', str(e)


def main():
    """
    Main function to load, process, and save the data.
    """
    print(f"Hugging Face cache directory set to: {os.environ.get('HF_HOME')}")
    print("Loading Mistral location extractor model (boods/mistral-location-extractor-4bit)...")
    
    try:
        # The model is already 4-bit, so no need for quantization_config
        pipe = pipeline(
            "text-generation",
            model="boods/mistral-location-extractor-4bit",
            torch_dtype=torch.bfloat16,
            device_map="auto"
        )
    except Exception as e:
        print(f"\nError loading the Hugging Face model: {e}")
        print("Please ensure you have run '!pip install transformers torch bitsandbytes accelerate' and have a stable internet connection.")
        return

    start_index = 0
    # **FIXED**: Check if a backup file exists to resume processing.
    if os.path.exists(BACKUP_FILENAME):
        print(f"Backup file found. Loading from '{BACKUP_FILENAME}' to resume.")
        df = pd.read_csv(BACKUP_FILENAME, engine='python', on_bad_lines='warn', quoting=csv.QUOTE_MINIMAL, keep_default_na=False)
        # Find the first row that is still marked as UNPROCESSED
        unprocessed_rows = df[df['Confidence'] == 'UNPROCESSED'].index
        if not unprocessed_rows.empty:
            start_index = unprocessed_rows.min()
        else:
            # If no unprocessed rows are found, all work is done.
            start_index = df.shape[0] 
        print(f"Resuming processing from row {start_index + 1}...")
    else:
        print(f"No backup file found. Starting from scratch with '{INPUT_FILENAME}'.")
        try:
            df = pd.read_csv(INPUT_FILENAME, engine='python', on_bad_lines='warn', quoting=csv.QUOTE_MINIMAL, keep_default_na=False)
            # **FIXED**: Initialize with a unique status to avoid ambiguity.
            df['Country'] = 'UNPROCESSED'
            df['Confidence'] = 'UNPROCESSED'
            df['Evidence'] = 'UNPROCESSED'
        except FileNotFoundError:
            print(f"Error: Input file '{INPUT_FILENAME}' not found.")
            return
        except Exception as e:
            print(f"An error occurred while reading the CSV: {e}")
            return

    print("Processing tweets with Mistral model...")
    
    # If start_index is at or beyond the end of the dataframe, we are done.
    if start_index >= df.shape[0]:
        print("All rows have already been processed. Nothing to do.")
    else:
        try:
            # Use iloc to process from the start_index and adjust tqdm.
            for index, row in tqdm(df.iloc[start_index:].iterrows(), total=df.shape[0], initial=start_index, desc="Analyzing tweets"):
                country, confidence, evidence = extract_country_info_mistral(row['text'], pipe)
                df.at[index, 'Country'] = country
                df.at[index, 'Confidence'] = confidence
                df.at[index, 'Evidence'] = evidence
                
                # The backup interval now works correctly with the resumed index
                if (index + 1) % BACKUP_INTERVAL == 0:
                    print(f"\nProcessed {index + 1} rows. Saving backup...")
                    df.to_csv(BACKUP_FILENAME, index=False, quoting=csv.QUOTE_ALL, na_rep='N/A')

        except KeyboardInterrupt:
            print("\nProcess interrupted. Saving partial results...")

    # Final save and summary
    print(f"\nSaving final data to '{OUTPUT_FILENAME}'...")
    try:
        df.to_csv(OUTPUT_FILENAME, index=False, quoting=csv.QUOTE_ALL, na_rep='N/A')
        print("Processing complete!")
        
        # Count found countries by excluding initial and error states.
        found_df = df[~df['Country'].isin(['N/A', 'UNPROCESSED', 'Error', 'Parse Error'])]
        print(f"\nFound countries in {len(found_df)} rows.")
        if not found_df.empty:
            print("Country distribution:\n", found_df['Country'].value_counts())
    except Exception as e:
        print(f"An error occurred while saving the final CSV: {e}")


if __name__ == "__main__":
    main()
# Out:
# Hugging Face cache directory set to: /scratch/project_2004147/.cache/huggingface/hub
# Loading Mistral location extractor model (boods/mistral-location-extractor-4bit)...
# config.json: 0.00B [00:00, ?B/s]
# /usr/local/lib/python3.12/site-packages/huggingface_hub/file_download.py:799: UserWarning: Not enough free disk space to download the file. The expected file size is: 4450.84 MB. The target location /users/karasovo/.cache/huggingface/hub/models--boods--mistral-location-extractor-4bit/blobs only has 3965.70 MB free disk space.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/4.45G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# /usr/local/lib/python3.12/site-packages/huggingface_hub/file_download.py:799: UserWarning: Not enough free disk space to download the file. The expected file size is: 3.51 MB. The target location /users/karasovo/.cache/huggingface/hub/models--boods--mistral-location-extractor-4bit/blobs only has 0.00 MB free disk space.
#   warnings.warn(
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Device set to use cuda:0
# No backup file found. Starting from scratch with '/projappl/project_2004147/visions/bertopic_with_zeroshot_chatgpt/df_with_final_predictions.csv'.
# Processing tweets with Mistral model...
# Analyzing tweets:   0%|          | 0/432 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   0%|          | 1/432 [00:05<37:23,  5.21s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   0%|          | 2/432 [00:07<23:29,  3.28s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   1%|          | 3/432 [00:09<18:49,  2.63s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   1%|          | 4/432 [00:10<16:24,  2.30s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   1%|          | 5/432 [00:12<15:36,  2.19s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   1%|▏         | 6/432 [00:14<14:53,  2.10s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   2%|▏         | 7/432 [00:17<15:57,  2.25s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   2%|▏         | 8/432 [00:19<15:11,  2.15s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   2%|▏         | 9/432 [00:21<14:26,  2.05s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   2%|▏         | 10/432 [00:22<14:02,  2.00s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   3%|▎         | 11/432 [00:24<13:48,  1.97s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   3%|▎         | 12/432 [00:26<13:40,  1.95s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   3%|▎         | 13/432 [00:28<13:34,  1.94s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   3%|▎         | 14/432 [00:30<13:38,  1.96s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   3%|▎         | 15/432 [00:32<14:02,  2.02s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   4%|▎         | 16/432 [00:34<13:34,  1.96s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   4%|▍         | 17/432 [00:36<13:33,  1.96s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   4%|▍         | 18/432 [00:38<13:26,  1.95s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   4%|▍         | 19/432 [00:41<14:44,  2.14s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   5%|▍         | 20/432 [00:42<14:04,  2.05s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   5%|▍         | 21/432 [00:44<13:39,  1.99s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   5%|▌         | 22/432 [00:46<13:32,  1.98s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   5%|▌         | 23/432 [00:48<13:17,  1.95s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   6%|▌         | 24/432 [00:50<13:12,  1.94s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   6%|▌         | 25/432 [00:52<12:54,  1.90s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   6%|▌         | 26/432 [00:54<12:52,  1.90s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   6%|▋         | 27/432 [00:56<12:52,  1.91s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   6%|▋         | 28/432 [00:58<12:41,  1.89s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   7%|▋         | 29/432 [01:00<14:03,  2.09s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   7%|▋         | 30/432 [01:02<13:54,  2.08s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   7%|▋         | 31/432 [01:05<14:49,  2.22s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   7%|▋         | 32/432 [01:07<13:58,  2.10s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   8%|▊         | 33/432 [01:08<13:34,  2.04s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   8%|▊         | 34/432 [01:10<13:23,  2.02s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   8%|▊         | 35/432 [01:12<12:57,  1.96s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   8%|▊         | 36/432 [01:14<12:37,  1.91s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   9%|▊         | 37/432 [01:16<12:35,  1.91s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   9%|▉         | 38/432 [01:18<12:35,  1.92s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   9%|▉         | 39/432 [01:20<12:34,  1.92s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   9%|▉         | 40/432 [01:22<12:21,  1.89s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:   9%|▉         | 41/432 [01:24<12:20,  1.89s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  10%|▉         | 42/432 [01:25<12:20,  1.90s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  10%|▉         | 43/432 [01:27<12:14,  1.89s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  10%|█         | 44/432 [01:30<13:40,  2.11s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  10%|█         | 45/432 [01:32<13:30,  2.09s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  11%|█         | 46/432 [01:34<13:04,  2.03s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  11%|█         | 47/432 [01:36<13:01,  2.03s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  11%|█         | 48/432 [01:38<14:03,  2.20s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  11%|█▏        | 49/432 [01:40<13:12,  2.07s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  12%|█▏        | 50/432 [01:42<12:54,  2.03s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  12%|█▏        | 51/432 [01:44<12:32,  1.98s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  12%|█▏        | 52/432 [01:46<12:15,  1.94s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  12%|█▏        | 53/432 [01:48<13:25,  2.13s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  12%|█▎        | 54/432 [01:50<13:03,  2.07s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  13%|█▎        | 55/432 [01:53<13:59,  2.23s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  13%|█▎        | 56/432 [01:55<13:23,  2.14s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  13%|█▎        | 57/432 [01:57<12:56,  2.07s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  13%|█▎        | 58/432 [01:59<12:27,  2.00s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  14%|█▎        | 59/432 [02:00<12:08,  1.95s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  14%|█▍        | 60/432 [02:03<13:18,  2.15s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  14%|█▍        | 61/432 [02:06<14:06,  2.28s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  14%|█▍        | 62/432 [02:08<13:35,  2.20s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  15%|█▍        | 63/432 [02:10<12:52,  2.09s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  15%|█▍        | 64/432 [02:11<12:31,  2.04s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  15%|█▌        | 65/432 [02:14<13:30,  2.21s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  15%|█▌        | 66/432 [02:16<12:57,  2.12s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  16%|█▌        | 67/432 [02:18<12:25,  2.04s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  16%|█▌        | 68/432 [02:20<12:03,  1.99s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  16%|█▌        | 69/432 [02:22<11:47,  1.95s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  16%|█▌        | 70/432 [02:23<11:43,  1.94s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  16%|█▋        | 71/432 [02:26<12:54,  2.15s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  17%|█▋        | 72/432 [02:28<12:40,  2.11s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  17%|█▋        | 73/432 [02:31<13:32,  2.26s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  17%|█▋        | 74/432 [02:33<12:56,  2.17s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  17%|█▋        | 75/432 [02:35<12:31,  2.11s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  18%|█▊        | 76/432 [02:37<12:21,  2.08s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  18%|█▊        | 77/432 [02:39<12:01,  2.03s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  18%|█▊        | 78/432 [02:41<11:52,  2.01s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  18%|█▊        | 79/432 [02:43<12:07,  2.06s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  19%|█▊        | 80/432 [02:45<11:45,  2.00s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  19%|█▉        | 81/432 [02:47<11:43,  2.01s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  19%|█▉        | 82/432 [02:49<11:29,  1.97s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  19%|█▉        | 83/432 [02:51<12:35,  2.16s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  19%|█▉        | 84/432 [02:53<12:09,  2.10s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  20%|█▉        | 85/432 [02:55<11:42,  2.02s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  20%|█▉        | 86/432 [02:58<12:39,  2.20s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  20%|██        | 87/432 [03:00<13:19,  2.32s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  20%|██        | 88/432 [03:02<12:30,  2.18s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  21%|██        | 89/432 [03:04<11:55,  2.08s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  21%|██        | 90/432 [03:06<12:24,  2.18s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  21%|██        | 91/432 [03:08<11:50,  2.08s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  21%|██▏       | 92/432 [03:10<11:26,  2.02s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  22%|██▏       | 93/432 [03:12<11:25,  2.02s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  22%|██▏       | 94/432 [03:15<12:26,  2.21s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  22%|██▏       | 95/432 [03:16<11:41,  2.08s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  22%|██▏       | 96/432 [03:18<11:26,  2.04s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  22%|██▏       | 97/432 [03:20<11:11,  2.01s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  23%|██▎       | 98/432 [03:23<12:09,  2.18s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  23%|██▎       | 99/432 [03:26<12:51,  2.32s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  23%|██▎       | 100/432 [03:27<12:04,  2.18s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  23%|██▎       | 101/432 [03:30<12:09,  2.20s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  24%|██▎       | 102/432 [03:32<11:38,  2.12s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  24%|██▍       | 103/432 [03:34<12:25,  2.26s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  24%|██▍       | 104/432 [03:37<12:57,  2.37s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  24%|██▍       | 105/432 [03:39<12:12,  2.24s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  25%|██▍       | 106/432 [03:41<12:45,  2.35s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  25%|██▍       | 107/432 [03:44<13:11,  2.44s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  25%|██▌       | 108/432 [03:46<12:13,  2.27s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  25%|██▌       | 109/432 [03:48<11:31,  2.14s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  25%|██▌       | 110/432 [03:50<11:31,  2.15s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  26%|██▌       | 111/432 [03:52<11:08,  2.08s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  26%|██▌       | 112/432 [03:54<11:22,  2.13s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  26%|██▌       | 113/432 [03:56<11:03,  2.08s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  26%|██▋       | 114/432 [03:58<11:24,  2.15s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  27%|██▋       | 115/432 [04:00<10:54,  2.06s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  27%|██▋       | 116/432 [04:02<10:32,  2.00s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  27%|██▋       | 117/432 [04:04<11:08,  2.12s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  27%|██▋       | 118/432 [04:06<10:56,  2.09s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  28%|██▊       | 119/432 [04:08<10:29,  2.01s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  28%|██▊       | 120/432 [04:10<10:16,  1.98s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  28%|██▊       | 121/432 [04:12<10:07,  1.95s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  28%|██▊       | 122/432 [04:14<09:53,  1.91s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  28%|██▊       | 123/432 [04:16<09:49,  1.91s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  29%|██▊       | 124/432 [04:18<10:47,  2.10s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  29%|██▉       | 125/432 [04:20<10:28,  2.05s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  29%|██▉       | 126/432 [04:23<10:51,  2.13s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  29%|██▉       | 127/432 [04:25<11:29,  2.26s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  30%|██▉       | 128/432 [04:27<10:55,  2.16s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  30%|██▉       | 129/432 [04:29<10:23,  2.06s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  30%|███       | 130/432 [04:31<11:03,  2.20s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  30%|███       | 131/432 [04:33<10:29,  2.09s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  31%|███       | 132/432 [04:35<10:12,  2.04s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  31%|███       | 133/432 [04:37<10:03,  2.02s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  31%|███       | 134/432 [04:39<09:48,  1.98s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  31%|███▏      | 135/432 [04:42<10:38,  2.15s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  31%|███▏      | 136/432 [04:44<11:15,  2.28s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  32%|███▏      | 137/432 [04:47<11:41,  2.38s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  32%|███▏      | 138/432 [04:49<11:58,  2.44s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  32%|███▏      | 139/432 [04:51<11:10,  2.29s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  32%|███▏      | 140/432 [04:53<10:21,  2.13s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  33%|███▎      | 141/432 [04:55<10:02,  2.07s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  33%|███▎      | 142/432 [04:58<10:45,  2.23s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  33%|███▎      | 143/432 [05:00<10:16,  2.13s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  33%|███▎      | 144/432 [05:01<09:48,  2.04s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  34%|███▎      | 145/432 [05:03<09:55,  2.08s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  34%|███▍      | 146/432 [05:05<09:25,  1.98s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  34%|███▍      | 147/432 [05:07<09:11,  1.94s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  34%|███▍      | 148/432 [05:09<09:02,  1.91s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  34%|███▍      | 149/432 [05:11<09:02,  1.92s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  35%|███▍      | 150/432 [05:13<09:00,  1.92s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  35%|███▍      | 151/432 [05:15<09:01,  1.93s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  35%|███▌      | 152/432 [05:17<09:01,  1.93s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  35%|███▌      | 153/432 [05:19<09:06,  1.96s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  36%|███▌      | 154/432 [05:21<09:02,  1.95s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  36%|███▌      | 155/432 [05:22<08:51,  1.92s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  36%|███▌      | 156/432 [05:25<09:04,  1.97s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  36%|███▋      | 157/432 [05:26<08:57,  1.96s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  37%|███▋      | 158/432 [05:28<08:50,  1.94s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  37%|███▋      | 159/432 [05:31<09:04,  2.00s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  37%|███▋      | 160/432 [05:32<08:57,  1.98s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  37%|███▋      | 161/432 [05:34<08:52,  1.97s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  38%|███▊      | 162/432 [05:37<09:41,  2.15s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  38%|███▊      | 163/432 [05:39<09:20,  2.08s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  38%|███▊      | 164/432 [05:41<09:04,  2.03s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  38%|███▊      | 165/432 [05:43<08:47,  1.98s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  38%|███▊      | 166/432 [05:45<08:56,  2.02s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  39%|███▊      | 167/432 [05:47<08:48,  1.99s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  39%|███▉      | 168/432 [05:49<08:42,  1.98s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  39%|███▉      | 169/432 [05:51<08:43,  1.99s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  39%|███▉      | 170/432 [05:53<08:40,  1.99s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  40%|███▉      | 171/432 [05:55<08:35,  1.97s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  40%|███▉      | 172/432 [05:57<09:21,  2.16s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  40%|████      | 173/432 [05:59<09:02,  2.09s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  40%|████      | 174/432 [06:01<08:40,  2.02s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  41%|████      | 175/432 [06:03<08:19,  1.94s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  41%|████      | 176/432 [06:05<08:13,  1.93s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  41%|████      | 177/432 [06:07<09:02,  2.13s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  41%|████      | 178/432 [06:09<08:40,  2.05s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  41%|████▏     | 179/432 [06:12<09:22,  2.22s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  42%|████▏     | 180/432 [06:14<09:49,  2.34s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  42%|████▏     | 181/432 [06:16<09:20,  2.23s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  42%|████▏     | 182/432 [06:18<08:56,  2.14s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  42%|████▏     | 183/432 [06:20<08:56,  2.16s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  43%|████▎     | 184/432 [06:22<08:42,  2.11s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  43%|████▎     | 185/432 [06:25<09:15,  2.25s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  43%|████▎     | 186/432 [06:27<08:42,  2.12s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  43%|████▎     | 187/432 [06:29<08:26,  2.07s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  44%|████▎     | 188/432 [06:31<08:15,  2.03s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  44%|████▍     | 189/432 [06:33<08:00,  1.98s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  44%|████▍     | 190/432 [06:35<07:56,  1.97s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  44%|████▍     | 191/432 [06:36<07:52,  1.96s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  44%|████▍     | 192/432 [06:39<08:37,  2.16s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  45%|████▍     | 193/432 [06:41<08:29,  2.13s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  45%|████▍     | 194/432 [06:43<08:10,  2.06s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  45%|████▌     | 195/432 [06:45<07:59,  2.02s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  45%|████▌     | 196/432 [06:48<08:37,  2.19s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  46%|████▌     | 197/432 [06:50<08:29,  2.17s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  46%|████▌     | 198/432 [06:52<08:10,  2.10s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  46%|████▌     | 199/432 [06:54<08:45,  2.26s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  46%|████▋     | 200/432 [06:56<08:34,  2.22s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  47%|████▋     | 201/432 [06:58<08:05,  2.10s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  47%|████▋     | 202/432 [07:00<07:52,  2.05s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  47%|████▋     | 203/432 [07:02<07:50,  2.06s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  47%|████▋     | 204/432 [07:05<08:26,  2.22s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  47%|████▋     | 205/432 [07:07<08:04,  2.13s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  48%|████▊     | 206/432 [07:09<07:55,  2.10s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  48%|████▊     | 207/432 [07:11<07:36,  2.03s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  48%|████▊     | 208/432 [07:13<08:13,  2.20s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  48%|████▊     | 209/432 [07:16<08:37,  2.32s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  49%|████▊     | 210/432 [07:18<08:08,  2.20s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  49%|████▉     | 211/432 [07:20<08:04,  2.19s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  49%|████▉     | 212/432 [07:22<07:51,  2.14s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  49%|████▉     | 213/432 [07:24<07:29,  2.05s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  50%|████▉     | 214/432 [07:26<07:08,  1.97s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  50%|████▉     | 215/432 [07:28<07:13,  2.00s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  50%|█████     | 216/432 [07:30<07:06,  1.97s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  50%|█████     | 217/432 [07:32<07:43,  2.16s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  50%|█████     | 218/432 [07:34<07:50,  2.20s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  51%|█████     | 219/432 [07:37<08:13,  2.32s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  51%|█████     | 220/432 [07:39<07:50,  2.22s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  51%|█████     | 221/432 [07:41<07:30,  2.14s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  51%|█████▏    | 222/432 [07:44<07:57,  2.27s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  52%|█████▏    | 223/432 [07:45<07:28,  2.15s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  52%|█████▏    | 224/432 [07:48<07:55,  2.29s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  52%|█████▏    | 225/432 [07:50<07:36,  2.21s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  52%|█████▏    | 226/432 [07:52<07:23,  2.15s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  53%|█████▎    | 227/432 [07:55<07:48,  2.29s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  53%|█████▎    | 228/432 [07:57<08:06,  2.38s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  53%|█████▎    | 229/432 [07:59<07:37,  2.25s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  53%|█████▎    | 230/432 [08:01<07:24,  2.20s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# ...
# Analyzing tweets:  84%|████████▎ | 361/432 [12:33<02:35,  2.19s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  84%|████████▍ | 362/432 [12:35<02:30,  2.15s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  84%|████████▍ | 363/432 [12:37<02:24,  2.09s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  84%|████████▍ | 364/432 [12:39<02:18,  2.04s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  84%|████████▍ | 365/432 [12:41<02:14,  2.01s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  85%|████████▍ | 366/432 [12:43<02:12,  2.00s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  85%|████████▍ | 367/432 [12:45<02:05,  1.94s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  85%|████████▌ | 368/432 [12:47<02:02,  1.92s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  85%|████████▌ | 369/432 [12:49<02:07,  2.02s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  86%|████████▌ | 370/432 [12:51<02:03,  1.99s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  86%|████████▌ | 371/432 [12:53<02:00,  1.98s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  86%|████████▌ | 372/432 [12:55<02:09,  2.17s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  86%|████████▋ | 373/432 [12:57<02:02,  2.07s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  87%|████████▋ | 374/432 [12:59<01:57,  2.02s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  87%|████████▋ | 375/432 [13:02<02:04,  2.18s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  87%|████████▋ | 376/432 [13:04<02:03,  2.20s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  87%|████████▋ | 377/432 [13:06<01:52,  2.05s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  88%|████████▊ | 378/432 [13:07<01:48,  2.01s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  88%|████████▊ | 379/432 [13:09<01:44,  1.98s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  88%|████████▊ | 380/432 [13:12<01:51,  2.14s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  88%|████████▊ | 381/432 [13:14<01:51,  2.18s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  88%|████████▊ | 382/432 [13:17<01:54,  2.30s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  89%|████████▊ | 383/432 [13:19<01:45,  2.14s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  89%|████████▉ | 384/432 [13:20<01:39,  2.08s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  89%|████████▉ | 385/432 [13:22<01:34,  2.02s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  89%|████████▉ | 386/432 [13:24<01:30,  1.97s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  90%|████████▉ | 387/432 [13:27<01:37,  2.17s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  90%|████████▉ | 388/432 [13:29<01:41,  2.30s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  90%|█████████ | 389/432 [13:31<01:34,  2.20s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  90%|█████████ | 390/432 [13:33<01:27,  2.09s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  91%|█████████ | 391/432 [13:35<01:26,  2.12s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  91%|█████████ | 392/432 [13:37<01:22,  2.05s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  91%|█████████ | 393/432 [13:39<01:18,  2.01s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  91%|█████████ | 394/432 [13:41<01:14,  1.97s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  91%|█████████▏| 395/432 [13:43<01:12,  1.96s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  92%|█████████▏| 396/432 [13:45<01:09,  1.94s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  92%|█████████▏| 397/432 [13:47<01:07,  1.94s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  92%|█████████▏| 398/432 [13:49<01:05,  1.93s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  92%|█████████▏| 399/432 [13:51<01:04,  1.96s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  93%|█████████▎| 400/432 [13:53<01:03,  1.99s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  93%|█████████▎| 401/432 [13:55<01:00,  1.95s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  93%|█████████▎| 402/432 [13:57<00:57,  1.91s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  93%|█████████▎| 403/432 [13:58<00:55,  1.90s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  94%|█████████▎| 404/432 [14:00<00:53,  1.91s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  94%|█████████▍| 405/432 [14:02<00:52,  1.93s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  94%|█████████▍| 406/432 [14:04<00:50,  1.94s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  94%|█████████▍| 407/432 [14:06<00:47,  1.89s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  94%|█████████▍| 408/432 [14:08<00:45,  1.89s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  95%|█████████▍| 409/432 [14:10<00:43,  1.91s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  95%|█████████▍| 410/432 [14:12<00:43,  1.97s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  95%|█████████▌| 411/432 [14:14<00:41,  1.99s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  95%|█████████▌| 412/432 [14:16<00:38,  1.92s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  96%|█████████▌| 413/432 [14:18<00:36,  1.93s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  96%|█████████▌| 414/432 [14:20<00:35,  1.99s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  96%|█████████▌| 415/432 [14:22<00:33,  1.95s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  96%|█████████▋| 416/432 [14:24<00:34,  2.14s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  97%|█████████▋| 417/432 [14:26<00:30,  2.05s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  97%|█████████▋| 418/432 [14:28<00:27,  1.99s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  97%|█████████▋| 419/432 [14:30<00:24,  1.92s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  97%|█████████▋| 420/432 [14:32<00:23,  1.93s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  97%|█████████▋| 421/432 [14:34<00:23,  2.13s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  98%|█████████▊| 422/432 [14:36<00:20,  2.05s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  98%|█████████▊| 423/432 [14:38<00:17,  1.99s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  98%|█████████▊| 424/432 [14:41<00:17,  2.17s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  98%|█████████▊| 425/432 [14:43<00:14,  2.10s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  99%|█████████▊| 426/432 [14:45<00:13,  2.25s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  99%|█████████▉| 427/432 [14:47<00:11,  2.20s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  99%|█████████▉| 428/432 [14:49<00:08,  2.12s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets:  99%|█████████▉| 429/432 [14:52<00:06,  2.26s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets: 100%|█████████▉| 430/432 [14:54<00:04,  2.30s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets: 100%|█████████▉| 431/432 [14:56<00:02,  2.16s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Analyzing tweets: 100%|██████████| 432/432 [14:58<00:00,  2.08s/it]
# Saving final data to '/projappl/project_2004147/visions/bertopic_with_zeroshot_chatgpt/df_with_geo_predictions_mistral_v2.csv'...
# Processing complete!
#
# Found countries in 351 rows.
# Country distribution:
#  Country
# Norway                    23
# Finland                   21
# Sweden                    19
# Spain                     18
# Italy                     17
# Ireland                   17
# Lithuania                 16
# Latvia                    15
# Kenya                     14
# Brazil                    14
# Poland                    14
# Germany                   13
# India                     13
# Canada                    12
# Netherlands               12
# Estonia                   11
# Ukraine                   11
# Portugal                  11
# Australia                 10
# UK                        10
# Wales                      9
# France                     7
# Iceland                    6
# United Kingdom             6
# USA                        6
# Belgium                    4
# Denmark                    4
# Australia, Catalonia       2
# Belgium, Germany           1
# Germany, Wales             1
# Latvia, Kenya              1
# Sicily, Estonia, Kenya     1
# European Union             1
# Sweden, Finland            1
# Canada, Kenya              1
# Canada, Wales              1
# Netherlands, Catalonia     1
# Ireland, Kenya             1
# Scotland                   1
# Iceland, Estonia           1
# Poland, Kenya              1
# Catalonia                  1
# Catalonia, Brazil          1
# United States              1
# Name: count, dtype: int64
